# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
from Model_Parent_2 import *
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from gplearn.genetic import SymbolicRegressor
import os

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv("../cleaned_data/auto_mpg_fixed_cleaned.csv", index_col=0)

# %%
df.drop('origin', axis=1, inplace=True)

# %%
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0         130    3504          12.0          70
# 1            8         350.0         165    3693          11.5          70
# 2            8         318.0         150    3436          11.0          70
# 3            8         304.0         150    3433          12.0          70
# 4            8         302.0         140    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0          86    2790          15.6          82
# 394          4          97.0          52    2130          24.6          82
# 395          4         135.0          84    2295          11.6          82
# 396          4         120.0          79    2625          18.6          82
# 397          4         119.0          82    2720          19.4          82
#
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [392 rows x 7 columns]

# %% [markdown]
# ## Breaking Data in X and y

# %%
X = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %% [markdown]
# ## Generating Models

# %% [markdown]
# ### Linear Regression

# %%
lr = linear_model.LinearRegression()

# %%
forwardSelection(lr, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:40:09   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['model_year', 'weight', 'displacement', 'cylinders', 'acceleration', 'horsepower']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.32389230284719395 | 0.32389230284719395 |  292.080191662823  | 294.44199609982354 |
# |     2.0      |  0.8036207049126081 |  0.8031171682585379 | 197.0805979159705  | 201.8042067899716  |
# |     3.0      |  0.8030326701254833 |  0.8020199846248429 | 199.32802232901736 | 206.41343564001903 |
# |     4.0      |  0.8016107314941779 |  0.8000767938510919 | 201.90709792315153 | 211.35431567115378 |
# |     5.0      |  0.7998403834303288 |  0.7977715501841307 | 204.66000886843364 | 216.46903105343645 |
# |     6.0      |  0.7984130642375619 |  0.7958018344997064 | 207.25756085913525 | 221.42838748113863 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:182: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lr, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:40:50   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['horsepower', 'acceleration', 'cylinders', 'displacement', 'weight', 'model_year']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     6.0      |  0.7984130642375618 |  0.7958018344997064 | 207.25756085913525 | 221.42838748113869 |
# |     5.0      |  0.7998403834303288 |  0.7977715501841306 | 204.66000886843366 | 216.46903105343648 |
# |     4.0      |  0.801610731494178  |  0.8000767938510919 | 201.90709792315153 | 211.35431567115376 |
# |     3.0      |  0.8030326701254829 |  0.8020199846248429 | 199.32802232901741 | 206.4134356400191  |
# |     2.0      |  0.8036207049126078 |  0.8031171682585377 | 197.08059791597057 | 201.80420678997166 |
# |     1.0      | 0.32389230284719395 | 0.32389230284719395 |  292.080191662823  | 294.44199609982354 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:282: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lr, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:40:56   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['horsepower', 'cylinders']
# Features Dropped: ['weight', 'model_year', 'acceleration', 'displacement']
# +--------------+---------------------+---------------------+-------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC        |        BIC         |
# +--------------+---------------------+---------------------+-------------------+--------------------+
# |     1.0      | 0.32389230284719395 | 0.32389230284719395 |  292.080191662823 | 294.44199609982354 |
# |     2.0      |  0.8036207049126081 |  0.8031171682585379 | 197.0805979159705 | 201.8042067899716  |
# +--------------+---------------------+---------------------+-------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:398: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Ridge Regression

# %%
ridge = linear_model.Ridge()

# %%
forwardSelection(ridge, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:23   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['model_year', 'weight', 'displacement', 'cylinders', 'acceleration', 'horsepower']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.32389543984920566 | 0.32389543984920566 | 292.0801556693008  | 292.0801556693008  |
# |     2.0      |  0.8036230338216173 |  0.8031195031391087 | 197.07922478145238 | 197.07922478145238 |
# |     3.0      |   0.80303523654194  |  0.802022564236243  | 199.3265329070798  | 199.3265329070798  |
# |     4.0      |  0.8016374775394702 |  0.8001037466957033 | 201.8959408277046  | 201.8959408277046  |
# |     5.0      |  0.7998691840630514 |  0.7978006484978117 | 204.64832149799915 | 204.64832149799915 |
# |     6.0      |  0.7984446498253374 |   0.79583382922722  | 207.24493904041614 | 207.24493904041614 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:182: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(ridge, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:23   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:282: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['horsepower', 'acceleration', 'cylinders', 'displacement', 'weight', 'model_year']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     6.0      |  0.7984446498253374 |  0.7958338292272199 | 207.2449390404161  | 207.2449390404161  |
# |     5.0      |  0.7998691840630514 |  0.7978006484978116 | 204.64832149799918 | 204.64832149799918 |
# |     4.0      |  0.8016374775394702 |  0.8001037466957032 | 201.89594082770458 | 201.89594082770458 |
# |     3.0      |   0.80303523654194  |  0.8020225642362432 | 199.32653290707978 | 199.32653290707978 |
# |     2.0      |  0.8036230338216173 |  0.8031195031391087 | 197.07922478145235 | 197.07922478145235 |
# |     1.0      | 0.32389543984920566 | 0.32389543984920566 | 292.0801556693008  | 292.0801556693008  |
# +--------------+---------------------+---------------------+--------------------+--------------------+

# %%
stepwiseSelection(ridge, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:24   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['horsepower', 'cylinders']
# Features Dropped: ['weight', 'model_year', 'acceleration', 'displacement']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.32389543984920566 | 0.32389543984920566 | 292.0801556693008  | 292.0801556693008  |
# |     2.0      |  0.8036230338216173 |  0.8031195031391087 | 197.07922478145238 | 197.07922478145238 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:398: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Lasso Regression

# %%
lasso = linear_model.Lasso()

# %%
forwardSelection(lasso, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:24   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['model_year', 'weight', 'displacement', 'cylinders', 'acceleration', 'horsepower']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.32323660775937935 | 0.32323660775937935 | 292.2380062837208  | 292.2380062837208  |
# |     2.0      |  0.8027365229468062 |  0.8022307191594903 | 197.1874012651842  | 197.1874012651842  |
# |     3.0      |  0.8022238811366433 |   0.80120703733786  | 199.39339007177483 | 199.39339007177483 |
# |     4.0      |  0.8022238811366433 |  0.8006946843413083 | 201.39339007177486 | 201.39339007177486 |
# |     5.0      |  0.8022238811366433 |  0.8001796835256526 | 203.39339007177486 | 203.39339007177486 |
# |     6.0      |  0.8007226883957849 |  0.7981413760693055 | 206.12296683261297 | 206.12296683261297 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:182: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lasso, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:24   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['horsepower', 'acceleration', 'cylinders', 'displacement', 'weight', 'model_year']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     6.0      |  0.8006976391656988 |  0.798116002367327  | 206.1357988912127  | 206.1357988912127  |
# |     5.0      |  0.8022033750442589 |  0.8001589654839929 | 203.40132371706903 | 203.40132371706903 |
# |     4.0      |  0.8022005816099146 |  0.8006712046635995 | 201.4024471855949  | 201.4024471855949  |
# |     3.0      |  0.8022011613543608 |  0.8011842007443575 | 199.40221287051003 | 199.40221287051003 |
# |     2.0      |  0.8027361892875401 |  0.8022303846446877 | 197.18752245491328 | 197.18752245491328 |
# |     1.0      | 0.32323660775937935 | 0.32323660775937935 | 292.2380062837208  | 292.2380062837208  |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:282: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lasso, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:24   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['horsepower', 'cylinders']
# Features Dropped: ['weight', 'model_year', 'acceleration', 'displacement']
# +--------------+---------------------+---------------------+-------------------+-------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC        |        BIC        |
# +--------------+---------------------+---------------------+-------------------+-------------------+
# |     1.0      | 0.32323660775937935 | 0.32323660775937935 | 292.2380062837208 | 292.2380062837208 |
# |     2.0      |  0.8027365229468062 |  0.8022307191594903 | 197.1874012651842 | 197.1874012651842 |
# +--------------+---------------------+---------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:398: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Symbolic Regression

# %%
sym_reg = SymbolicRegressor()

# %%
forwardSelection(sym_reg, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        16:37:25   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/rz/09rsx9gn7_v672b_tqbwk_g80000gn/T/ipykernel_8312/2857638255.py in <module>
# ----> 1 forwardSelection(sym_reg, X, y)
#
# ~/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py in forwardSelection(model, X, y)
#     128             y_test = fold[3]
#     129
# --> 130             model.fit(X_train, y_train)
#     131             y_pred = model.predict(X_test)
#     132
#
# ~/miniforge3/lib/python3.9/site-packages/gplearn/genetic.py in fit(self, X, y, sample_weight)
#     460             seeds = random_state.randint(MAX_INT, size=self.population_size)
#     461
# --> 462             population = Parallel(n_jobs=n_jobs,
#     463                                   verbose=int(self.verbose > 1))(
#     464                 delayed(_parallel_evolve)(n_programs[i],
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniforge3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniforge3/lib/python3.9/site-packages/gplearn/genetic.py in _parallel_evolve(n_programs, parents, X, y, sample_weight, seeds, params)
#      70     for i in range(n_programs):
#      71
# ---> 72         random_state = check_random_state(seeds[i])
#      73
#      74         if parents is None:
#
# ~/miniforge3/lib/python3.9/site-packages/gplearn/utils.py in check_random_state(seed)
#      28         return np.random.mtrand._rand
#      29     if isinstance(seed, (numbers.Integral, np.integer)):
# ---> 30         return np.random.RandomState(seed)
#      31     if isinstance(seed, np.random.RandomState):
#      32         return seed
#
# mtrand.pyx in numpy.random.mtrand.RandomState.__init__()
#
# _mt19937.pyx in numpy.random._mt19937.MT19937.__init__()
#
# ~/miniforge3/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# KeyboardInterrupt:

# %%
backwardSelection(sym_reg, X, y)

# %%
stepwiseSelection(sym_reg, X, y)

# %% [markdown]
# ### Quadratic Regression

# %%
# Not working yet

# %%
quad_reg = PolynomialFeatures(degree=2)
X_quad = quad_reg.fit_transform(X)
X_col_names = X.columns.to_list()
X_quad = pd.DataFrame(X_quad)
lr_q = linear_model.LinearRegression()

# %%
forwardSelection(lr_q, X_quad, y)

# %%
backwardSelection(lr_q, X_quad, y)

# %%
stepwiseSelection(lr_q, X_quad, y)

# %% [markdown]
# ### Cubic Regression

# %%
# Not working yet

# %%
cubic_reg = PolynomialFeatures(degree=3)
X_cubic = cubic_reg.fit_transform(X)
lr_c = linear_model.LinearRegression()

# %%
forwardSelection(lr_c, X_cubic, y)

# %%
backwardSelection(lr_c, X_cubic, y)

# %%
stepwiseSelection(lr_c, X_cubic, y)
