# %%
import numpy as np
import pandas as pd
from Model_Parent_2 import *
import os

# %%
df = pd.read_csv("../cleaned_data/auto_mpg_fixed_cleaned.csv", index_col=0)

# %%
df.drop('origin', axis=1, inplace=True)

# %%
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0         130    3504          12.0          70
# 1            8         350.0         165    3693          11.5          70
# 2            8         318.0         150    3436          11.0          70
# 3            8         304.0         150    3433          12.0          70
# 4            8         302.0         140    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0          86    2790          15.6          82
# 394          4          97.0          52    2130          24.6          82
# 395          4         135.0          84    2295          11.6          82
# 396          4         120.0          79    2625          18.6          82
# 397          4         119.0          82    2720          19.4          82
#
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [392 rows x 7 columns]

# %%
X = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
forwardSelection(model, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        11:13:13   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['model_year', 'weight', 'displacement', 'cylinders', 'acceleration', 'horsepower']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.32389230284719395 | 0.32389230284719395 | 213.77535569265822 | 227.99204280746034 |
# |     2.0      |  0.8036207049126081 |  0.8031171682585379 | 207.62110508303672 | 221.83779219783884 |
# |     3.0      |  0.8030326701254833 |  0.8020199846248429 | 226.1629355210058  | 240.30318848114337 |
# |     4.0      |  0.8016107314941779 |  0.8000767938510919 | 200.59000622166712 | 214.73025918180468 |
# |     5.0      |  0.7998403834303288 |  0.7977715501841307 | 188.1384017773084  | 202.27865473744595 |
# |     6.0      |  0.7984130642375619 |  0.7958018344997064 | 207.25756085913525 | 207.25756085913528 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:182: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(model, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     272.2
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):          3.79e-135
# Time:                        11:14:43   Log-Likelihood:                -1036.5
# No. Observations:                 392   AIC:                             2087.
# Df Residuals:                     385   BIC:                             2115.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -14.5353      4.764     -3.051      0.002     -23.902      -5.169
# cylinders       -0.3299      0.332     -0.993      0.321      -0.983       0.323
# displacement     0.0077      0.007      1.044      0.297      -0.007       0.022
# horsepower      -0.0004      0.014     -0.028      0.977      -0.028       0.027
# weight          -0.0068      0.001    -10.141      0.000      -0.008      -0.005
# acceleration     0.0853      0.102      0.836      0.404      -0.115       0.286
# model_year       0.7534      0.053     14.318      0.000       0.650       0.857
# ==============================================================================
# Omnibus:                       37.865   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.248
# Skew:                           0.630   Prob(JB):                     8.26e-14
# Kurtosis:                       4.449   Cond. No.                     8.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['horsepower', 'acceleration', 'cylinders', 'displacement', 'weight', 'model_year']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     6.0      |  0.7984130642375618 |  0.7958018344997064 | 292.6366792147432  | 295.00612706721023 |
# |     5.0      |  0.7998403834303288 |  0.7977715501841306 | 291.4588687332125  | 293.82831658567954 |
# |     4.0      |  0.801610731494178  |  0.8000767938510919 | 299.60608726764264 | 301.96279609433225 |
# |     3.0      |  0.8030326701254829 |  0.8020199846248429 | 291.5369717735482  | 293.8936806002378  |
# |     2.0      |  0.8036207049126078 |  0.8031171682585377 | 285.1623513249683  | 287.5190601516579  |
# |     1.0      | 0.32389230284719395 | 0.32389230284719395 |  292.080191662823  |  292.080191662823  |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:282: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
