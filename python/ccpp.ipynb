# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from gplearn.genetic import SymbolicRegressor
import os
import seaborn as sns
import matplotlib.pyplot as plt

from Model_Parent import *
from Model_Parent_2 import *

# %% [markdown]
# ## Importing Data

# %%
df = pd.read_csv("../cleaned_data/ccpp.csv", index_col=0)

# %%
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# ## Checking Data

# %%
# Check to make sure that no columns have perfect colinearity

# %%
corr_mat = df.corr(method='pearson')
sns.heatmap(corr_mat, cmap='vlag')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Breaking Data in X and y

# %%
X = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %% [markdown]
# ## Generating Models

# %% [markdown]
# ### Linear Regression

# %%
lr = linear_model.LinearRegression()

# %%
forwardSelection(lr, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:41   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['AT', 'RH', 'V', 'AP']
# +--------------+--------------------+--------------------+--------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC         |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |     1.0      | 0.8987798176281563 | 0.8987798176281563 | 6472.5183125751555 | 6472.5183125751555 |
# |     2.0      | 0.9207903141325865 | 0.9207820337974549 |  6006.68490755051  |  6006.68490755051  |
# |     3.0      | 0.9282177167685657 | 0.9282027074045864 | 5820.090419743586  | 5820.090419743586  |
# |     4.0      | 0.9285086820880141 | 0.9284862569569249 | 5814.271606694855  | 5814.271606694855  |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lr, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:42   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['AP', 'V', 'RH', 'AT']
# +--------------+--------------------+--------------------+--------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC        |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# |     4.0      | 0.9285086820880141 | 0.9284862569569249 | 5814.271606694854  | 5836.498572818789 |
# |     3.0      | 0.9282177167685657 | 0.9282027074045864 | 5820.090419743585  | 5836.760644336538 |
# |     2.0      | 0.9207903141325865 | 0.9207820337974549 |  6006.68490755051  | 6017.798390612477 |
# |     1.0      | 0.8987798176281563 | 0.8987798176281563 | 6472.5183125751555 |  6478.07505410614 |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lr, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:42   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['AT', 'AP', 'RH', 'V']
# Features Dropped: []
# +--------------+--------------------+--------------------+--------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC        |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# |     1.0      | 0.8987798176281563 | 0.8987798176281563 | 6472.5183125751555 |  6478.07505410614 |
# |     2.0      | 0.9207903141325865 | 0.9207820337974549 |  6006.68490755051  | 6017.798390612477 |
# |     3.0      | 0.9282177167685657 | 0.9282027074045864 | 5820.090419743586  | 5836.760644336537 |
# |     4.0      | 0.9285086820880141 | 0.9284862569569249 | 5814.271606694855  | 5836.498572818791 |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Ridge Regression

# %%
ridge = linear_model.Ridge()

# %%
forwardSelection(ridge, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:43   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['AT', 'RH', 'V', 'AP']
# +--------------+--------------------+--------------------+-------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC        |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# |     1.0      | 0.898779818068574  | 0.898779818068574  | 6472.518334188369 | 6472.518334188369 |
# |     2.0      | 0.9207903143934857 | 0.9207820340583815 | 6006.684910182537 | 6006.684910182537 |
# |     3.0      | 0.928217718059847  | 0.9282027086961377 | 5820.090378747716 | 5820.090378747716 |
# |     4.0      | 0.9285086821418027 | 0.9284862570107304 |  5814.27159975462 |  5814.27159975462 |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(ridge, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:43   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['AP', 'V', 'RH', 'AT']
# +--------------+--------------------+--------------------+-------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC         |
# +--------------+--------------------+--------------------+-------------------+--------------------+
# |     4.0      | 0.9285086821418027 | 0.9284862570107304 |  5814.27159975462 | 5836.498565878556  |
# |     3.0      | 0.9282177180598472 | 0.9282027086961377 | 5820.090378747715 | 5836.7606033406655 |
# |     2.0      | 0.9207903143934857 | 0.9207820340583815 | 6006.684910182537 | 6017.798393244505  |
# |     1.0      | 0.898779818068574  | 0.898779818068574  | 6472.518334188369 | 6478.075075719353  |
# +--------------+--------------------+--------------------+-------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(ridge, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:43   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['AT', 'AP', 'RH', 'V']
# Features Dropped: []
# +--------------+--------------------+--------------------+-------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC        |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# |     1.0      | 0.898779818068574  | 0.898779818068574  | 6472.518334188369 | 6478.075075719353 |
# |     2.0      | 0.9207903143934857 | 0.9207820340583815 | 6006.684910182537 | 6017.798393244505 |
# |     3.0      | 0.928217718059847  | 0.9282027086961377 | 5820.090378747716 | 5836.760603340667 |
# |     4.0      | 0.9285086821418027 | 0.9284862570107304 |  5814.27159975462 | 5836.498565878554 |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Lasso Regression

# %%
lasso = linear_model.Lasso()

# %%
forwardSelection(lasso, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:44   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['AT', 'RH', 'V', 'AP']
# +--------------+--------------------+--------------------+-------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC        |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# |     1.0      | 0.8987193825973441 | 0.8987193825973441 | 6473.769114904559 | 6473.769114904559 |
# |     2.0      | 0.9206307671351862 | 0.920622470121506  | 6010.498346082975 | 6010.498346082975 |
# |     3.0      | 0.9280086764025004 | 0.9279936233290874 | 5825.574018639675 | 5825.574018639675 |
# |     4.0      | 0.9282888009418444 | 0.9282663068392543 |  5820.09516972118 |  5820.09516972118 |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lasso, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:44   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['AP', 'V', 'RH', 'AT']
# +--------------+--------------------+--------------------+-------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC        |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# |     4.0      | 0.928289220279796  | 0.9282667263087419 | 5820.084315969872 | 5842.311282093807 |
# |     3.0      | 0.9280092138026635 | 0.9279941608416188 | 5825.560129703188 | 5842.230354296139 |
# |     2.0      | 0.9206307671351862 | 0.920622470121506  | 6010.498346082975 | 6021.611829144943 |
# |     1.0      | 0.8987193825973441 | 0.8987193825973441 | 6473.769114904559 | 6479.325856435544 |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lasso, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:45   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['AT', 'AP', 'RH', 'V']
# Features Dropped: []
# +--------------+--------------------+--------------------+-------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC        |        BIC        |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# |     1.0      | 0.8987193825973441 | 0.8987193825973441 | 6473.769114904559 | 6479.325856435544 |
# |     2.0      | 0.9206307671351862 | 0.920622470121506  | 6010.498346082975 | 6021.611829144943 |
# |     3.0      | 0.9280086764025004 | 0.9279936233290874 | 5825.574018639675 | 5842.244243232626 |
# |     4.0      | 0.9282888009418444 | 0.9282663068392543 |  5820.09516972118 | 5842.322135845115 |
# +--------------+--------------------+--------------------+-------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Symbolic Regression

# %%
sym_reg = SymbolicRegressor()

# %%
forwardSelection(sym_reg, X, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:40:45   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['AT', 'RH', 'V', 'AP']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      |  0.3105044024017585 |  0.3105044024017585 | 8822.467474511195  | 8822.467474511195  |
# |     2.0      | -269.29412671341146 | -269.32238242391884 | 14837.183746947723 | 14837.183746947723 |
# |     3.0      |  -8.372322003619184 |  -8.374281715486118 | 15072.866945303196 | 15072.866945303196 |
# |     4.0      | 0.47314020223463443 | 0.47297493880999053 | 8791.293381401414  | 8791.293381401414  |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(sym_reg, X, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:46:05   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['AP', 'V', 'RH', 'AT']
# +--------------+--------------------+--------------------+--------------------+-------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC        |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# |     4.0      | 0.6034835822246272 | 0.6033592044273326 | 8182.976713935046  | 8205.203680058981 |
# |     3.0      | -8.70118533153655  | -8.703213807298503 | 15191.05126907283  | 15207.72149366578 |
# |     2.0      | -46.58840612522944 | -46.59338086975434 | 16061.763998677474 | 16072.87748173944 |
# |     1.0      | -5.142235834546371 | -5.142235834546371 | 12105.796689257244 | 12111.35343078823 |
# +--------------+--------------------+--------------------+--------------------+-------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(sym_reg, X, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                 3.114e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:51:58   Log-Likelihood:                -28088.
# No. Observations:                9568   AIC:                         5.619e+04
# Df Residuals:                    9563   BIC:                         5.622e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        454.6093      9.749     46.634      0.000     435.500     473.718
# AT            -1.9775      0.015   -129.342      0.000      -2.007      -1.948
# V             -0.2339      0.007    -32.122      0.000      -0.248      -0.220
# AP             0.0621      0.009      6.564      0.000       0.044       0.081
# RH            -0.1581      0.004    -37.918      0.000      -0.166      -0.150
# ==============================================================================
# Omnibus:                      892.002   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4086.777
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                       6.123   Cond. No.                     2.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['AT', 'V']
# Features Dropped: ['AP', 'RH']
# +--------------+--------------------+--------------------+--------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC         |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |     1.0      | 0.8341472197687663 | 0.8341472197687663 | 7249.0263551060125 | 7254.583096636996  |
# |     2.0      | 0.847873702739457  | 0.8478577999277007 |  7147.90935428971  | 7159.0228373516775 |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Quadratic Regression

# %%
quad_reg = PolynomialFeatures(degree=2)
X_quad = quad_reg.fit_transform(X)
X_quad = pd.DataFrame(X_quad, columns=quad_reg.get_feature_names())
lr_q = linear_model.LinearRegression()
X_quad.apply(lambda col: col.reset_index(drop=True))
X_quad = X_quad.drop(columns = ["1"])
y_quad = y.reset_index(drop=True)
X_quad
# Out:
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/venv3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#          x0     x1       x2     x3      x0^2      x0 x1       x0 x2  \
# 0     14.96  41.76  1024.07  73.17  223.8016   624.7296  15320.0872
# 1     25.18  62.96  1020.04  59.08  634.0324  1585.3328  25684.6072
# 2      5.11  39.40  1012.16  92.14   26.1121   201.3340   5172.1376
# 3     20.86  57.32  1010.24  76.64  435.1396  1195.6952  21073.6064
# 4     10.82  37.50  1009.23  96.62  117.0724   405.7500  10919.8686
# ...     ...    ...      ...    ...       ...        ...         ...
# 9563  16.65  49.69  1014.01  91.00  277.2225   827.3385  16883.2665
# 9564  13.19  39.18  1023.67  66.78  173.9761   516.7842  13502.2073
# 9565  31.32  74.33  1012.92  36.48  980.9424  2328.0156  31724.6544
# 9566  24.48  69.45  1013.86  62.39  599.2704  1700.1360  24819.2928
# 9567  21.60  62.52  1017.23  67.87  466.5600  1350.4320  21972.1680
#
#           x0 x3       x1^2       x1 x2      x1 x3          x2^2       x2 x3  \
# 0     1094.6232  1743.8976  42765.1632  3055.5792  1.048719e+06  74931.2019
# 1     1487.6344  3963.9616  64221.7184  3719.6768  1.040482e+06  60263.9632
# 2      470.8354  1552.3600  39879.1040  3630.3160  1.024468e+06  93260.4224
# 3     1598.7104  3285.5824  57906.9568  4393.0048  1.020585e+06  77424.7936
# 4     1045.4284  1406.2500  37846.1250  3623.2500  1.018545e+06  97511.8026
# ...         ...        ...         ...        ...           ...         ...
# 9563  1515.1500  2469.0961  50386.1569  4521.7900  1.028216e+06  92274.9100
# 9564   880.8282  1535.0724  40107.3906  2616.4404  1.047900e+06  68360.6826
# 9565  1142.5536  5524.9489  75290.3436  2711.5584  1.026007e+06  36951.3216
# 9566  1527.3072  4823.3025  70412.5770  4332.9855  1.027912e+06  63254.7254
# 9567  1465.9920  3908.7504  63597.2196  4243.2324  1.034757e+06  69039.4001
#
#            x3^2
# 0     5353.8489
# 1     3490.4464
# 2     8489.7796
# 3     5873.6896
# 4     9335.4244
# ...         ...
# 9563  8281.0000
# 9564  4459.5684
# 9565  1330.7904
# 9566  3892.5121
# 9567  4606.3369
#
# [9568 rows x 14 columns]

# %%
forwardSelection(lr_q, X_quad, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.030e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:43   Log-Likelihood:                -27431.
# No. Observations:                9568   AIC:                         5.489e+04
# Df Residuals:                    9553   BIC:                         5.500e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7503.7323   1207.276     -6.215      0.000   -9870.250   -5137.214
# x0            -5.7969      3.092     -1.875      0.061     -11.858       0.264
# x1            -3.0443      1.498     -2.033      0.042      -5.980      -0.109
# x2            15.6284      2.341      6.677      0.000      11.040      20.216
# x3             3.9194      0.879      4.458      0.000       2.196       5.643
# x0^2           0.0163      0.003      5.307      0.000       0.010       0.022
# x0 x1          0.0120      0.003      4.463      0.000       0.007       0.017
# x0 x2          0.0031      0.003      1.037      0.300      -0.003       0.009
# x0 x3         -0.0061      0.001     -4.056      0.000      -0.009      -0.003
# x1^2          -0.0013      0.001     -1.606      0.108      -0.003       0.000
# x1 x2          0.0026      0.001      1.765      0.078      -0.000       0.005
# x1 x3          0.0005      0.001      0.765      0.444      -0.001       0.002
# x2^2          -0.0076      0.001     -6.706      0.000      -0.010      -0.005
# x2 x3         -0.0036      0.001     -4.262      0.000      -0.005      -0.002
# x3^2          -0.0019      0.000     -7.256      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     1629.849   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11134.924
# Skew:                          -0.642   Prob(JB):                         0.00
# Kurtosis:                       8.127   Cond. No.                     2.86e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.86e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['x3^2', 'x2^2', 'x2', 'x0^2', 'x0 x1', 'x3', 'x2 x3', 'x0 x3', 'x1', 'x0', 'x1 x2', 'x1^2', 'x0 x2', 'x1 x3']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.14997189853724768 | 0.14997189853724768 | 10547.630690983426 | 10547.630690983426 |
# |     2.0      |  0.3852103816669684 |  0.3851461134651774 | 9928.602413049708  | 9928.602413049708  |
# |     3.0      | 0.38756220774712535 |  0.3874341496619705 | 9923.298725265657  | 9923.298725265657  |
# |     4.0      |  0.8596038469502622 |  0.8595598080063948 | 7106.227634793531  | 7106.227634793531  |
# |     5.0      |  0.8834678701541705 |  0.8834191272367402 | 6752.286082036121  | 6752.286082036121  |
# |     6.0      |   0.88507277004483  |  0.8850126742333077 | 6728.073169056237  | 6728.073169056237  |
# |     7.0      |  0.8864874961277096 |  0.8864162614217965 | 6706.225637378806  | 6706.225637378806  |
# |     8.0      |  0.9304344943098808 |  0.9303835572241244 | 5770.267870767251  | 5770.267870767251  |
# |     9.0      |  0.9320934025744989 |  0.9320365710252361 |  5725.87971495851  |  5725.87971495851  |
# |     10.0     |  0.9373968030458937 |  0.9373378546495148 | 5571.975614576331  | 5571.975614576331  |
# |     11.0     |  0.9374932520435604 |  0.9374278478916753 | 5570.904055162716  | 5570.904055162716  |
# |     12.0     |  0.9374975966477562 |  0.9374256495530645 |  5572.74312203826  |  5572.74312203826  |
# |     13.0     |  0.9374969595479369 |  0.9374184627938369 | 5574.781347339966  | 5574.781347339966  |
# |     14.0     |  0.9374735229343735 |  0.9373884439934219 | 5577.5131130841455 | 5577.5131130841455 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lr_q, X_quad, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.030e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:44   Log-Likelihood:                -27431.
# No. Observations:                9568   AIC:                         5.489e+04
# Df Residuals:                    9553   BIC:                         5.500e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7503.7323   1207.276     -6.215      0.000   -9870.250   -5137.214
# x0            -5.7969      3.092     -1.875      0.061     -11.858       0.264
# x1            -3.0443      1.498     -2.033      0.042      -5.980      -0.109
# x2            15.6284      2.341      6.677      0.000      11.040      20.216
# x3             3.9194      0.879      4.458      0.000       2.196       5.643
# x0^2           0.0163      0.003      5.307      0.000       0.010       0.022
# x0 x1          0.0120      0.003      4.463      0.000       0.007       0.017
# x0 x2          0.0031      0.003      1.037      0.300      -0.003       0.009
# x0 x3         -0.0061      0.001     -4.056      0.000      -0.009      -0.003
# x1^2          -0.0013      0.001     -1.606      0.108      -0.003       0.000
# x1 x2          0.0026      0.001      1.765      0.078      -0.000       0.005
# x1 x3          0.0005      0.001      0.765      0.444      -0.001       0.002
# x2^2          -0.0076      0.001     -6.706      0.000      -0.010      -0.005
# x2 x3         -0.0036      0.001     -4.262      0.000      -0.005      -0.002
# x3^2          -0.0019      0.000     -7.256      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     1629.849   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11134.924
# Skew:                          -0.642   Prob(JB):                         0.00
# Kurtosis:                       8.127   Cond. No.                     2.86e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.86e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['x1 x3', 'x0 x2', 'x1^2', 'x1 x2', 'x0', 'x1', 'x0 x3', 'x2 x3', 'x3', 'x0 x1', 'x0^2', 'x2', 'x2^2', 'x3^2']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     14.0     |  0.9374735229343412 |  0.9373884439933894 |  5577.51311308501  | 5655.307494518784  |
# |     13.0     |  0.9374969595479519 |  0.9374184627938519 | 5574.781347339485  | 5647.018987242275  |
# |     12.0     |  0.9374975966477598 |  0.9374256495530681 | 5572.743122038137  | 5639.424020409942  |
# |     11.0     |  0.9374932520435942 |  0.9374278478917093 | 5570.904055161825  | 5632.028212002649  |
# |     10.0     |  0.9373968030458542 |  0.9373378546494754 | 5571.9756145775755 | 5627.543029887415  |
# |     9.0      |  0.9320934025744467 |  0.9320365710251837 | 5725.879714959963  | 5775.890388738817  |
# |     8.0      |  0.9304344943098901 |  0.9303835572241337 | 5770.267870767033  | 5814.721803014904  |
# |     7.0      |  0.8864874961277172 |  0.8864162614218042 | 6706.225637378663  |  6745.12282809555  |
# |     6.0      |  0.8850727700448286 |  0.8850126742333064 | 6728.0731690562625 | 6761.413618242164  |
# |     5.0      |  0.8834678701541685 |  0.8834191272367384 |  6752.28608203615  | 6780.069789691069  |
# |     4.0      |  0.8596038469502663 |  0.8595598080063986 | 7106.227634793477  | 7128.454600917413  |
# |     3.0      | 0.38756220774712846 | 0.38743414966197354 | 9923.298725265655  | 9939.968949858605  |
# |     2.0      | 0.38521038166696836 | 0.38514611346517735 |  9928.60241304971  | 9939.715896111677  |
# |     1.0      | 0.14997189853724768 | 0.14997189853724768 | 10547.630690983426 | 10553.187432514407 |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lr_q, X_quad, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                 1.030e+04
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:45   Log-Likelihood:                -27431.
# No. Observations:                9568   AIC:                         5.489e+04
# Df Residuals:                    9553   BIC:                         5.500e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7503.7323   1207.276     -6.215      0.000   -9870.250   -5137.214
# x0            -5.7969      3.092     -1.875      0.061     -11.858       0.264
# x1            -3.0443      1.498     -2.033      0.042      -5.980      -0.109
# x2            15.6284      2.341      6.677      0.000      11.040      20.216
# x3             3.9194      0.879      4.458      0.000       2.196       5.643
# x0^2           0.0163      0.003      5.307      0.000       0.010       0.022
# x0 x1          0.0120      0.003      4.463      0.000       0.007       0.017
# x0 x2          0.0031      0.003      1.037      0.300      -0.003       0.009
# x0 x3         -0.0061      0.001     -4.056      0.000      -0.009      -0.003
# x1^2          -0.0013      0.001     -1.606      0.108      -0.003       0.000
# x1 x2          0.0026      0.001      1.765      0.078      -0.000       0.005
# x1 x3          0.0005      0.001      0.765      0.444      -0.001       0.002
# x2^2          -0.0076      0.001     -6.706      0.000      -0.010      -0.005
# x2 x3         -0.0036      0.001     -4.262      0.000      -0.005      -0.002
# x3^2          -0.0019      0.000     -7.256      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     1629.849   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11134.924
# Skew:                          -0.642   Prob(JB):                         0.00
# Kurtosis:                       8.127   Cond. No.                     2.86e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.86e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['x1 x3', 'x1^2', 'x2', 'x0 x1', 'x3', 'x0^2', 'x0 x2', 'x0 x3', 'x2^2', 'x3^2', 'x0', 'x1']
# Features Dropped: ['x2 x3', 'x1 x2']
# +--------------+---------------------+---------------------+--------------------+--------------------+
# | Num_Features |        r2_cv        |        r2_bar       |        AIC         |        BIC         |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# |     1.0      | 0.14997189853724768 | 0.14997189853724768 | 10547.630690983426 | 10553.187432514407 |
# |     2.0      |  0.3852103816669684 |  0.3851461134651774 | 9928.602413049708  | 9939.715896111677  |
# |     3.0      | 0.38756220774712535 |  0.3874341496619705 | 9923.298725265657  |  9939.96894985861  |
# |     4.0      |  0.8596038469502622 |  0.8595598080063948 | 7106.227634793531  | 7128.454600917465  |
# |     5.0      |  0.8834678701541705 |  0.8834191272367402 | 6752.286082036121  | 6780.069789691041  |
# |     6.0      |   0.88507277004483  |  0.8850126742333077 | 6728.073169056237  |  6761.41361824214  |
# |     7.0      |  0.8864874961277096 |  0.8864162614217965 | 6706.225637378806  | 6745.122828095693  |
# |     8.0      |  0.9304344943098808 |  0.9303835572241244 | 5770.267870767251  | 5814.721803015122  |
# |     9.0      |  0.9320934025744989 |  0.9320365710252361 |  5725.87971495851  | 5775.890388737364  |
# |     10.0     |  0.9373968030458937 |  0.9373378546495148 | 5571.975614576331  |  5627.54302988617  |
# |     11.0     |  0.9374932520435604 |  0.9374278478916753 | 5570.904055162716  | 5632.028212003538  |
# |     12.0     |  0.9374975966477562 |  0.9374256495530645 |  5572.74312203826  | 5639.424020410066  |
# +--------------+---------------------+---------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Cubic Regression

# %%
cub_reg = PolynomialFeatures(degree=3)
X_cubic = cub_reg.fit_transform(X)
X_cubic = pd.DataFrame(X_cubic, columns=cub_reg.get_feature_names())
lr_c = linear_model.LinearRegression()
X_cubic.apply(lambda col: col.reset_index(drop=True))
X_cubic = X_cubic.drop(columns = ["1"])
y_cub = y.reset_index(drop=True)
X_cubic
# Out:
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/venv3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#          x0     x1       x2     x3      x0^2      x0 x1       x0 x2  \
# 0     14.96  41.76  1024.07  73.17  223.8016   624.7296  15320.0872
# 1     25.18  62.96  1020.04  59.08  634.0324  1585.3328  25684.6072
# 2      5.11  39.40  1012.16  92.14   26.1121   201.3340   5172.1376
# 3     20.86  57.32  1010.24  76.64  435.1396  1195.6952  21073.6064
# 4     10.82  37.50  1009.23  96.62  117.0724   405.7500  10919.8686
# ...     ...    ...      ...    ...       ...        ...         ...
# 9563  16.65  49.69  1014.01  91.00  277.2225   827.3385  16883.2665
# 9564  13.19  39.18  1023.67  66.78  173.9761   516.7842  13502.2073
# 9565  31.32  74.33  1012.92  36.48  980.9424  2328.0156  31724.6544
# 9566  24.48  69.45  1013.86  62.39  599.2704  1700.1360  24819.2928
# 9567  21.60  62.52  1017.23  67.87  466.5600  1350.4320  21972.1680
#
#           x0 x3       x1^2       x1 x2  ...           x1^3       x1^2 x2  \
# 0     1094.6232  1743.8976  42765.1632  ...   72825.163776  1.785873e+06
# 1     1487.6344  3963.9616  64221.7184  ...  249571.022336  4.043399e+06
# 2      470.8354  1552.3600  39879.1040  ...   61162.984000  1.571237e+06
# 3     1598.7104  3285.5824  57906.9568  ...  188329.583168  3.319227e+06
# 4     1045.4284  1406.2500  37846.1250  ...   52734.375000  1.419230e+06
# ...         ...        ...         ...  ...            ...           ...
# 9563  1515.1500  2469.0961  50386.1569  ...  122689.385209  2.503688e+06
# 9564   880.8282  1535.0724  40107.3906  ...   60144.136632  1.571408e+06
# 9565  1142.5536  5524.9489  75290.3436  ...  410669.451737  5.596331e+06
# 9566  1527.3072  4823.3025  70412.5770  ...  334978.358625  4.890153e+06
# 9567  1465.9920  3908.7504  63597.2196  ...  244375.075008  3.976098e+06
#
#             x1^2 x3       x1 x2^2      x1 x2 x3        x1 x3^2          x2^3  \
# 0     127600.987392  4.379452e+07  3.129127e+06  223576.730064  1.073962e+09
# 1     234190.851328  6.550872e+07  3.794219e+06  219758.505344  1.061333e+09
# 2     143034.450400  4.036403e+07  3.674461e+06  334497.316240  1.036925e+09
# 3     251807.035136  5.849992e+07  4.437989e+06  336679.887872  1.031036e+09
# 4     135871.875000  3.819544e+07  3.656693e+06  350078.415000  1.027946e+09
# ...             ...           ...           ...            ...           ...
# 9563  224687.745100  5.109207e+07  4.585140e+06  411482.890000  1.042622e+09
# 9564  102512.134872  4.105673e+07  2.678372e+06  174725.889912  1.072704e+09
# 9565  201550.135872  7.626309e+07  2.746592e+06   98917.650432  1.039263e+09
# 9566  300925.842975  7.138850e+07  4.393041e+06  270334.965345  1.042159e+09
# 9567  265286.889648  6.469300e+07  4.316343e+06  287988.182988  1.052586e+09
#
#            x2^2 x3       x2 x3^2           x3^3
# 0     7.673480e+07  5.482716e+06  391741.124013
# 1     6.147165e+07  3.560395e+06  206215.573312
# 2     9.439447e+07  8.593015e+06  782248.292344
# 3     7.821762e+07  5.933836e+06  450159.570944
# 4     9.841184e+07  9.421590e+06  901988.705528
# ...            ...           ...            ...
# 9563  9.356768e+07  8.397017e+06  753571.000000
# 9564  6.997878e+07  4.565126e+06  297809.977752
# 9565  3.742873e+07  1.347984e+06   48547.233792
# 9566  6.413144e+07  3.946462e+06  242853.829919
# 9567  7.022895e+07  4.685704e+06  312632.085403
#
# [9568 rows x 34 columns]

# %%
forwardSelection(lr_c, X_cubic, y)
# Out:
# FORWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     4586.
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:46   Log-Likelihood:                -27203.
# No. Observations:                9568   AIC:                         5.447e+04
# Df Residuals:                    9534   BIC:                         5.472e+04
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2317      0.737      0.314      0.753      -1.213       1.676
# x0            33.8342    352.093      0.096      0.923    -656.343     724.011
# x1          -538.1161    218.855     -2.459      0.014    -967.119    -109.113
# x2            17.6098     10.574      1.665      0.096      -3.117      38.337
# x3           -41.8436    103.301     -0.405      0.685    -244.336     160.648
# x0^2          -1.1257      0.647     -1.739      0.082      -2.395       0.143
# x0 x1          0.9857      0.645      1.528      0.126      -0.279       2.250
# x0 x2         -0.1345      0.688     -0.196      0.845      -1.483       1.214
# x0 x3          0.7448      0.304      2.449      0.014       0.149       1.341
# x1^2           0.9468      0.200      4.743      0.000       0.555       1.338
# x1 x2          0.9618      0.427      2.254      0.024       0.126       1.798
# x1 x3         -0.3423      0.148     -2.313      0.021      -0.632      -0.052
# x2^2          -0.0290      0.021     -1.410      0.159      -0.069       0.011
# x2 x3          0.0442      0.200      0.221      0.825      -0.348       0.436
# x3^2           0.3308      0.059      5.593      0.000       0.215       0.447
# x0^3           0.0005      0.000      1.036      0.300      -0.000       0.001
# x0^2 x1        0.0015      0.001      2.642      0.008       0.000       0.003
# x0^2 x2        0.0011      0.001      1.745      0.081      -0.000       0.002
# x0^2 x3       -0.0010      0.000     -3.092      0.002      -0.002      -0.000
# x0 x1^2       -0.0014      0.000     -4.877      0.000      -0.002      -0.001
# x0 x1 x2      -0.0010      0.001     -1.536      0.125      -0.002       0.000
# x0 x1 x3       0.0013      0.000      4.451      0.000       0.001       0.002
# x0 x2^2     9.644e-05      0.000      0.287      0.774      -0.001       0.001
# x0 x2 x3      -0.0007      0.000     -2.404      0.016      -0.001      -0.000
# x0 x3^2       -0.0004      0.000     -3.813      0.000      -0.001      -0.000
# x1^3           0.0005   6.69e-05      7.999      0.000       0.000       0.001
# x1^2 x2       -0.0010      0.000     -4.963      0.000      -0.001      -0.001
# x1^2 x3       -0.0003      8e-05     -4.364      0.000      -0.001      -0.000
# x1 x2^2       -0.0004      0.000     -2.032      0.042      -0.001    -1.5e-05
# x1 x2 x3       0.0003      0.000      2.288      0.022    4.71e-05       0.001
# x1 x3^2        0.0001   4.71e-05      3.082      0.002    5.28e-05       0.000
# x2^3        1.194e-05      1e-05      1.193      0.233   -7.68e-06    3.16e-05
# x2^2 x3     -3.54e-06   9.71e-05     -0.036      0.971      -0.000       0.000
# x2 x3^2       -0.0003   5.68e-05     -5.570      0.000      -0.000      -0.000
# x3^3       -5.505e-05   1.59e-05     -3.457      0.001   -8.63e-05   -2.38e-05
# ==============================================================================
# Omnibus:                     1798.630   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13664.566
# Skew:                          -0.696   Prob(JB):                         0.00
# Kurtosis:                       8.687   Cond. No.                     3.31e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# FORWARD SELECTION SUMMARY TABLE:
#
# Features In Order Added: ['x1^3', 'x3^2', 'x2 x3^2', 'x1^2 x2', 'x0 x1^2', 'x1^2', 'x0 x1 x3', 'x1^2 x3', 'x0 x3^2', 'x3^3', 'x0^2 x3', 'x1 x3^2', 'x0^2 x1', 'x1', 'x0 x3', 'x0 x2 x3', 'x1 x3', 'x1 x2 x3', 'x1 x2', 'x1 x2^2', 'x0^2 x2', 'x0^2', 'x2', 'x0 x1 x2', 'x0 x1', 'x2^2', 'x2^3', 'x0^3', 'x3', 'x0 x2^2', 'x2 x3', 'x0 x2', 'x0', 'x2^2 x3']
# +--------------+--------------------+--------------------+--------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC         |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |     1.0      | 0.6999718662024537 | 0.6999718662024537 |  8554.67499288558  |  8554.67499288558  |
# |     2.0      | 0.7213016410734294 | 0.7212725068105268 | 8415.497004668165  | 8415.497004668165  |
# |     3.0      | 0.7518505850625518 | 0.7517986980965429 | 8195.385677017599  | 8195.385677017599  |
# |     4.0      | 0.810194381892806  | 0.8101348443714421 |  7684.16896589612  |  7684.16896589612  |
# |     5.0      | 0.8775320828611104 | 0.8774808571297964 | 6847.511806072202  | 6847.511806072202  |
# |     6.0      | 0.8776880199987162 | 0.8776240626780712 |  6847.06875382587  |  6847.06875382587  |
# |     7.0      | 0.9076414983220593 | 0.9075835387979438 | 6311.618550635734  | 6311.618550635734  |
# |     8.0      | 0.9179540013261374 | 0.9178939258040957 | 6086.794667103466  | 6086.794667103466  |
# |     9.0      | 0.9233833033673893 | 0.9233191822696739 | 5957.099999221235  | 5957.099999221235  |
# |     10.0     | 0.9266621672603014 | 0.9265931109206218 | 5874.4136979404675 | 5874.4136979404675 |
# |     11.0     | 0.9277354792405449 | 0.9276598650093432 | 5848.052563216297  | 5848.052563216297  |
# |     12.0     |  0.92787546116522  | 0.9277924379413625 | 5846.549289533517  | 5846.549289533517  |
# |     13.0     | 0.9281019674866273 | 0.9280116716844127 | 5842.382485951193  | 5842.382485951193  |
# |     14.0     | 0.9282269842132548 | 0.9281293236307524 | 5840.855462093792  | 5840.855462093792  |
# |     15.0     | 0.9367103029823669 | 0.9366175514113161 | 5601.757951185104  | 5601.757951185104  |
# |     16.0     | 0.9370930547400104 | 0.9369942687078809 | 5592.270185895933  | 5592.270185895933  |
# |     17.0     | 0.9379760255518319 | 0.9378721219196289 | 5567.604086187619  | 5567.604086187619  |
# |     18.0     | 0.9380644737975123 | 0.9379542220754764 | 5566.814343374491  | 5566.814343374491  |
# |     19.0     | 0.9381985545491464 | 0.9380820579507467 | 5564.876485120195  | 5564.876485120195  |
# |     20.0     | 0.9388436592408487 | 0.9387219614534142 | 5546.873780702581  | 5546.873780702581  |
# |     21.0     | 0.9393507246515614 | 0.939223670550067  |  5533.11641788889  |  5533.11641788889  |
# |     22.0     | 0.9395584385379449 | 0.9394254747006621 | 5528.4038858117465 | 5528.4038858117465 |
# |     23.0     | 0.9401052736382812 | 0.9399672239808734 | 5512.849202860122  | 5512.849202860122  |
# |     24.0     | 0.9401240359272238 | 0.9399797413784314 | 5514.245640068716  | 5514.245640068716  |
# |     25.0     | 0.9401091261185371 | 0.939958504618678  | 5516.696200852124  | 5516.696200852124  |
# |     26.0     | 0.9400954891918145 | 0.9399385396246164 | 5519.126681464794  | 5519.126681464794  |
# |     27.0     | 0.9401663264318063 | 0.9400032748111403 | 5518.876874445641  | 5518.876874445641  |
# |     28.0     | 0.9401543932743973 | 0.9399850189157399 | 5521.301970621808  | 5521.301970621808  |
# |     29.0     | 0.940144059790045  | 0.9399683635613126 | 5523.643489251171  | 5523.643489251171  |
# |     30.0     | 0.9401684441690505 | 0.939986528136434  | 5524.861119351743  | 5524.861119351743  |
# |     31.0     | 0.9401935994213433 | 0.9400054698190198 | 5525.944738716181  | 5525.944738716181  |
# |     32.0     | 0.9402379809022413 | 0.9400437042042515 | 5526.533253554121  | 5526.533253554121  |
# |     33.0     | 0.9402365702100562 | 0.9400360007550714 | 5528.567453508511  | 5528.567453508511  |
# |     34.0     | 0.940269868806392  | 0.9400631251175533 | 5529.542962088522  | 5529.542962088522  |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:239: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
backwardSelection(lr_c, X_cubic, y)
# Out:
# BACKWARD SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     4586.
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:48   Log-Likelihood:                -27203.
# No. Observations:                9568   AIC:                         5.447e+04
# Df Residuals:                    9534   BIC:                         5.472e+04
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2317      0.737      0.314      0.753      -1.213       1.676
# x0            33.8342    352.093      0.096      0.923    -656.343     724.011
# x1          -538.1161    218.855     -2.459      0.014    -967.119    -109.113
# x2            17.6098     10.574      1.665      0.096      -3.117      38.337
# x3           -41.8436    103.301     -0.405      0.685    -244.336     160.648
# x0^2          -1.1257      0.647     -1.739      0.082      -2.395       0.143
# x0 x1          0.9857      0.645      1.528      0.126      -0.279       2.250
# x0 x2         -0.1345      0.688     -0.196      0.845      -1.483       1.214
# x0 x3          0.7448      0.304      2.449      0.014       0.149       1.341
# x1^2           0.9468      0.200      4.743      0.000       0.555       1.338
# x1 x2          0.9618      0.427      2.254      0.024       0.126       1.798
# x1 x3         -0.3423      0.148     -2.313      0.021      -0.632      -0.052
# x2^2          -0.0290      0.021     -1.410      0.159      -0.069       0.011
# x2 x3          0.0442      0.200      0.221      0.825      -0.348       0.436
# x3^2           0.3308      0.059      5.593      0.000       0.215       0.447
# x0^3           0.0005      0.000      1.036      0.300      -0.000       0.001
# x0^2 x1        0.0015      0.001      2.642      0.008       0.000       0.003
# x0^2 x2        0.0011      0.001      1.745      0.081      -0.000       0.002
# x0^2 x3       -0.0010      0.000     -3.092      0.002      -0.002      -0.000
# x0 x1^2       -0.0014      0.000     -4.877      0.000      -0.002      -0.001
# x0 x1 x2      -0.0010      0.001     -1.536      0.125      -0.002       0.000
# x0 x1 x3       0.0013      0.000      4.451      0.000       0.001       0.002
# x0 x2^2     9.644e-05      0.000      0.287      0.774      -0.001       0.001
# x0 x2 x3      -0.0007      0.000     -2.404      0.016      -0.001      -0.000
# x0 x3^2       -0.0004      0.000     -3.813      0.000      -0.001      -0.000
# x1^3           0.0005   6.69e-05      7.999      0.000       0.000       0.001
# x1^2 x2       -0.0010      0.000     -4.963      0.000      -0.001      -0.001
# x1^2 x3       -0.0003      8e-05     -4.364      0.000      -0.001      -0.000
# x1 x2^2       -0.0004      0.000     -2.032      0.042      -0.001    -1.5e-05
# x1 x2 x3       0.0003      0.000      2.288      0.022    4.71e-05       0.001
# x1 x3^2        0.0001   4.71e-05      3.082      0.002    5.28e-05       0.000
# x2^3        1.194e-05      1e-05      1.193      0.233   -7.68e-06    3.16e-05
# x2^2 x3     -3.54e-06   9.71e-05     -0.036      0.971      -0.000       0.000
# x2 x3^2       -0.0003   5.68e-05     -5.570      0.000      -0.000      -0.000
# x3^3       -5.505e-05   1.59e-05     -3.457      0.001   -8.63e-05   -2.38e-05
# ==============================================================================
# Omnibus:                     1798.630   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13664.566
# Skew:                          -0.696   Prob(JB):                         0.00
# Kurtosis:                       8.687   Cond. No.                     3.31e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# BACKWARD SELECTION SUMMARY TABLE:
#
# Features In Order Removed: ['x2^2 x3', 'x0', 'x0 x2', 'x2 x3', 'x0 x2^2', 'x3', 'x0^3', 'x2^3', 'x2^2', 'x0 x1', 'x0 x1 x2', 'x2', 'x0^2', 'x0^2 x2', 'x1 x2^2', 'x1 x2', 'x1 x2 x3', 'x1 x3', 'x0 x2 x3', 'x0 x3', 'x1', 'x0^2 x1', 'x1 x3^2', 'x0^2 x3', 'x3^3', 'x0 x3^2', 'x1^2 x3', 'x0 x1 x3', 'x1^2', 'x0 x1^2', 'x1^2 x2', 'x2 x3^2', 'x3^2', 'x1^3']
# +--------------+--------------------+--------------------+--------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC         |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |     34.0     | 0.9402698735206407 | 0.9400631298481192 | 5529.542808616747  | 5718.472020670196  |
# |     33.0     | 0.940236571716933  | 0.9400360022670056 | 5528.567397788519  | 5711.939868310985  |
# |     32.0     | 0.9402379775642473 | 0.9400437008554062 | 5526.533356212647  | 5704.3490852041305 |
# |     31.0     | 0.9401935958103508 | 0.9400054661966681 | 5525.944857642649  | 5698.203845103149  |
# |     30.0     | 0.9401684446709307 | 0.9399865286398399 | 5524.8611037686405 | 5691.563349698155  |
# |     29.0     | 0.9401440650842577 | 0.9399683688710656 | 5523.643328293933  | 5684.788832692464  |
# |     28.0     | 0.9401543960337962 | 0.9399850216829485 | 5521.301887257456  | 5676.890650125003  |
# |     27.0     | 0.9401663254045445 | 0.9400032737810793 | 5518.876920443951  | 5668.908941780514  |
# |     26.0     | 0.9400954892056795 | 0.9399385396385178 | 5519.126681099777  | 5663.6019609053565 |
# |     25.0     | 0.940109126126736  | 0.9399585046268977 | 5516.696200609173  | 5655.614738883769  |
# |     24.0     | 0.9401240359333061 | 0.9399797413845283 | 5514.245639889223  | 5647.607436632834  |
# |     23.0     | 0.9401052736428162 | 0.9399672239854189 | 5512.849202741874  | 5640.654257954503  |
# |     22.0     | 0.9395584385386766 | 0.9394254747013951 | 5528.403885789995  | 5650.6521994716395 |
# |     21.0     | 0.9393507246514133 | 0.9392236705499185 | 5533.116417893708  | 5649.807990044368  |
# |     20.0     | 0.9388436592405867 | 0.9387219614531519 |  5546.87378070993  | 5658.0086113296065 |
# |     19.0     | 0.9381985545490494 | 0.9380820579506498 | 5564.876485123039  | 5670.4545742117325 |
# |     18.0     | 0.9380644737973813 | 0.9379542220753454 | 5566.814343378137  | 5666.835690935845  |
# |     17.0     | 0.9379760255516579 | 0.9378721219194548 | 5567.604086192861  | 5662.068692219586  |
# |     16.0     | 0.9370930547399551 | 0.9369942687078255 | 5592.270185897755  | 5681.178050393498  |
# |     15.0     | 0.9367103029823187 | 0.936617551411268  |  5601.75795118651  | 5685.109074151268  |
# |     14.0     | 0.9282269842132453 | 0.9281293236307431 | 5840.855462094013  | 5918.649843527785  |
# |     13.0     | 0.9281019674866287 | 0.9280116716844141 | 5842.382485951175  | 5914.620125853964  |
# |     12.0     | 0.927875461165204  | 0.9277924379413462 | 5846.549289533951  | 5913.230187905758  |
# |     11.0     | 0.9277354792405417 | 0.9276598650093402 | 5848.052563216413  | 5909.176720057234  |
# |     10.0     | 0.926662167260319  | 0.9265931109206396 | 5874.413697940024  | 5929.981113249863  |
# |     9.0      | 0.9233833033673913 | 0.9233191822696758 |  5957.0999992212   | 6007.110673000054  |
# |     8.0      | 0.9179540013261368 | 0.9178939258040953 | 6086.794667103473  | 6131.248599351345  |
# |     7.0      | 0.9076414983220646 | 0.9075835387979492 |  6311.61855063561  | 6350.515741352496  |
# |     6.0      | 0.8776880199987008 | 0.8776240626780561 | 6847.0687538261045 | 6880.409203012008  |
# |     5.0      | 0.8775320828611235 | 0.8774808571298097 | 6847.511806072002  | 6875.295513726921  |
# |     4.0      | 0.8101943818927694 | 0.8101348443714057 | 7684.168965896492  | 7706.3959320204285 |
# |     3.0      | 0.7518505850625457 | 0.7517986980965368 | 8195.385677017646  | 8212.055901610596  |
# |     2.0      | 0.7213016410734294 | 0.7212725068105269 | 8415.497004668165  | 8426.610487730131  |
# |     1.0      | 0.6999718662024537 | 0.6999718662024537 |  8554.67499288558  | 8560.231734416564  |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:348: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
stepwiseSelection(lr_c, X_cubic, y)
# Out:
# STEPWISE SELECTION REPORT:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PE   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     4586.
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:57:50   Log-Likelihood:                -27203.
# No. Observations:                9568   AIC:                         5.447e+04
# Df Residuals:                    9534   BIC:                         5.472e+04
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2317      0.737      0.314      0.753      -1.213       1.676
# x0            33.8342    352.093      0.096      0.923    -656.343     724.011
# x1          -538.1161    218.855     -2.459      0.014    -967.119    -109.113
# x2            17.6098     10.574      1.665      0.096      -3.117      38.337
# x3           -41.8436    103.301     -0.405      0.685    -244.336     160.648
# x0^2          -1.1257      0.647     -1.739      0.082      -2.395       0.143
# x0 x1          0.9857      0.645      1.528      0.126      -0.279       2.250
# x0 x2         -0.1345      0.688     -0.196      0.845      -1.483       1.214
# x0 x3          0.7448      0.304      2.449      0.014       0.149       1.341
# x1^2           0.9468      0.200      4.743      0.000       0.555       1.338
# x1 x2          0.9618      0.427      2.254      0.024       0.126       1.798
# x1 x3         -0.3423      0.148     -2.313      0.021      -0.632      -0.052
# x2^2          -0.0290      0.021     -1.410      0.159      -0.069       0.011
# x2 x3          0.0442      0.200      0.221      0.825      -0.348       0.436
# x3^2           0.3308      0.059      5.593      0.000       0.215       0.447
# x0^3           0.0005      0.000      1.036      0.300      -0.000       0.001
# x0^2 x1        0.0015      0.001      2.642      0.008       0.000       0.003
# x0^2 x2        0.0011      0.001      1.745      0.081      -0.000       0.002
# x0^2 x3       -0.0010      0.000     -3.092      0.002      -0.002      -0.000
# x0 x1^2       -0.0014      0.000     -4.877      0.000      -0.002      -0.001
# x0 x1 x2      -0.0010      0.001     -1.536      0.125      -0.002       0.000
# x0 x1 x3       0.0013      0.000      4.451      0.000       0.001       0.002
# x0 x2^2     9.644e-05      0.000      0.287      0.774      -0.001       0.001
# x0 x2 x3      -0.0007      0.000     -2.404      0.016      -0.001      -0.000
# x0 x3^2       -0.0004      0.000     -3.813      0.000      -0.001      -0.000
# x1^3           0.0005   6.69e-05      7.999      0.000       0.000       0.001
# x1^2 x2       -0.0010      0.000     -4.963      0.000      -0.001      -0.001
# x1^2 x3       -0.0003      8e-05     -4.364      0.000      -0.001      -0.000
# x1 x2^2       -0.0004      0.000     -2.032      0.042      -0.001    -1.5e-05
# x1 x2 x3       0.0003      0.000      2.288      0.022    4.71e-05       0.001
# x1 x3^2        0.0001   4.71e-05      3.082      0.002    5.28e-05       0.000
# x2^3        1.194e-05      1e-05      1.193      0.233   -7.68e-06    3.16e-05
# x2^2 x3     -3.54e-06   9.71e-05     -0.036      0.971      -0.000       0.000
# x2 x3^2       -0.0003   5.68e-05     -5.570      0.000      -0.000      -0.000
# x3^3       -5.505e-05   1.59e-05     -3.457      0.001   -8.63e-05   -2.38e-05
# ==============================================================================
# Omnibus:                     1798.630   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13664.566
# Skew:                          -0.696   Prob(JB):                         0.00
# Kurtosis:                       8.687   Cond. No.                     3.31e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# STEPWISE SELECTION SUMMARY TABLE:
#
# Features Added: ['x0 x1', 'x1', 'x0', 'x2^2', 'x1 x2', 'x0 x3^2', 'x0^2 x2', 'x2^3', 'x0 x1 x2', 'x2^2 x3', 'x1 x2 x3', 'x0 x2^2', 'x0 x2 x3', 'x3^2', 'x1^2 x3', 'x2', 'x0^2 x3', 'x3', 'x3^3', 'x0^3', 'x1 x3', 'x0 x1^2', 'x2 x3^2', 'x1 x2^2', 'x0^2']
# Features Dropped: ['x1^2', 'x1 x3^2', 'x2 x3', 'x0 x3', 'x1^2 x2', 'x0^2 x1', 'x0 x1 x3', 'x1^3', 'x0 x2']
# +--------------+--------------------+--------------------+--------------------+--------------------+
# | Num_Features |       r2_cv        |       r2_bar       |        AIC         |        BIC         |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |     1.0      | 0.6999718662024537 | 0.6999718662024537 |  8554.67499288558  | 8560.231734416564  |
# |     2.0      | 0.7213016410734294 | 0.7212725068105268 | 8415.497004668165  | 8426.610487730131  |
# |     3.0      | 0.7518505850625518 | 0.7517986980965429 | 8195.385677017599  |  8212.05590161055  |
# |     4.0      | 0.810194381892806  | 0.8101348443714421 |  7684.16896589612  | 7706.3959320200565 |
# |     5.0      | 0.8775320828611104 | 0.8774808571297964 | 6847.511806072202  | 6875.295513727123  |
# |     6.0      | 0.8776880199987162 | 0.8776240626780712 |  6847.06875382587  | 6880.409203011773  |
# |     7.0      | 0.9076414983220593 | 0.9075835387979438 | 6311.618550635734  | 6350.515741352621  |
# |     8.0      | 0.9179540013261374 | 0.9178939258040957 | 6086.794667103466  | 6131.248599351336  |
# |     9.0      | 0.9233833033673893 | 0.9233191822696739 | 5957.099999221235  | 6007.110673000088  |
# |     10.0     | 0.9266621672603014 | 0.9265931109206218 | 5874.4136979404675 | 5929.9811132503055 |
# |     11.0     | 0.9277354792405449 | 0.9276598650093432 | 5848.052563216297  | 5909.176720057119  |
# |     12.0     |  0.92787546116522  | 0.9277924379413625 | 5846.549289533517  | 5913.230187905324  |
# |     13.0     | 0.9281019674866273 | 0.9280116716844127 | 5842.382485951193  | 5914.620125853982  |
# |     14.0     | 0.9282269842132548 | 0.9281293236307524 | 5840.855462093792  | 5918.649843527565  |
# |     15.0     | 0.9367103029823669 | 0.9366175514113161 | 5601.757951185104  | 5685.109074149861  |
# |     16.0     | 0.9370930547400104 | 0.9369942687078809 | 5592.270185895933  | 5681.178050391674  |
# |     17.0     | 0.9379760255518319 | 0.9378721219196289 | 5567.604086187619  | 5662.068692214345  |
# |     18.0     | 0.9380644737975123 | 0.9379542220754764 | 5566.814343374491  |  5666.8356909322   |
# |     19.0     | 0.9381985545491464 | 0.9380820579507467 | 5564.876485120195  | 5670.454574208888  |
# |     20.0     | 0.9388436592408487 | 0.9387219614534142 | 5546.873780702581  | 5658.008611322258  |
# |     21.0     | 0.9393507246515614 | 0.939223670550067  |  5533.11641788889  | 5649.807990039551  |
# |     22.0     | 0.9395584385379449 | 0.9394254747006621 | 5528.4038858117465 | 5650.652199493391  |
# |     23.0     | 0.9401052736382812 | 0.9399672239808734 | 5512.849202860122  |  5640.65425807275  |
# |     24.0     | 0.9401240359272238 | 0.9399797413784314 | 5514.245640068716  | 5647.607436812328  |
# |     25.0     | 0.9401625798997294 | 0.9400120928325173 |  5515.08641989098  | 5654.004958165577  |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# /Users/sdk/Desktop/UGA_proj/DS2_P1/python/Model_Parent_2.py:479: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
